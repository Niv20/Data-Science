# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Part 1
#
# Create a jupyter notebook with exercises for the **basic python features** we have learned in class. Write the exercises, and also sulutions for them.

# %% [markdown]
# ### Part 2
#
# Create a jupyter notebook with exercises for the **numpy features** we have learned in class. Write the exercises, and also sulutions for them.

# %% [markdown]
# ### Part 3
#
# Create a jupyter notebook with exercises for the **pandas features** we have learned in class. Write the exercises, and also sulutions for them. In these exercises, make sure you also practice *visualization* tools.

# %% [markdown]
# Here are some examples of such notebooks, for inspiration:

# %% [markdown]
# - [Kaggle pandas course-Grouping & Sorting](https://www.kaggle.com/code/scratchpad/notebook035302e875/edit)
#
# - [numpy](https://colab.research.google.com/github/sbu-python-class/python-science/blob/main/content/02-numpy/numpy-exercises.ipynb#scrollTo=tIBf2eiTdCVN)
#
# - [matplotlib](https://colab.research.google.com/drive/11UKGDHPy0XAiqeesCGD6DRNXyvrR7Ml-#scrollTo=bTKzY0IWQrCt)
#
# - [python-Strings and Dictionaries](https://www.kaggle.com/code/scratchpad/notebook65e22963e0/edit)
